# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
df = pd.read_csv('Smart-Warehouse-Delay/data/train.csv')
df
# Out:
#                   ID layout_id scenario_id  order_inflow_15m  unique_sku_15m  \
# 0       TRAIN_000000    WH_136    SC_07598              51.0            96.0
# 1       TRAIN_000001    WH_136    SC_07598               NaN            93.0
# 2       TRAIN_000002    WH_136    SC_07598              92.0           115.0
# 3       TRAIN_000003    WH_136    SC_07598              77.0           110.0
# 4       TRAIN_000004    WH_136    SC_07598               NaN           122.0
# ...              ...       ...         ...               ...             ...
# 249995  TRAIN_249995    WH_174    SC_05114              39.0             NaN
# 249996  TRAIN_249996    WH_174    SC_05114              69.0            96.0
# 249997  TRAIN_249997    WH_174    SC_05114              61.0           123.0
# 249998  TRAIN_249998    WH_174    SC_05114              54.0            97.0
# 249999  TRAIN_249999    WH_174    SC_05114              48.0            69.0
#
#         avg_items_per_order  urgent_order_ratio  heavy_item_ratio  \
# 0                      3.29              0.1176            0.1765
# 1                      2.55              0.0597               NaN
# 2                      2.49              0.0652            0.2283
# 3                      2.52              0.0649               NaN
# 4                      3.12              0.0667            0.3333
# ...                     ...                 ...               ...
# 249995                 2.28              0.0513            0.1795
# 249996                 2.22              0.0870            0.2319
# 249997                 2.62              0.0984            0.3934
# 249998                 2.65              0.1296            0.1667
# 249999                 2.35              0.0625            0.2500
#
#         cold_chain_ratio  sku_concentration  ...  racking_height_avg_m  \
# 0                 0.0392             0.3063  ...                   NaN
# 1                 0.0149                NaN  ...                  2.50
# 2                 0.0217             0.3063  ...                  3.87
# 3                 0.0390             0.3063  ...                  2.50
# 4                    NaN             0.3063  ...                   NaN
# ...                  ...                ...  ...                   ...
# 249995               NaN                NaN  ...                  8.10
# 249996            0.0290             0.2226  ...                  8.63
# 249997            0.0820             0.2226  ...                   NaN
# 249998            0.0185             0.2226  ...                  9.39
# 249999               NaN             0.2226  ...                  7.58
#
#         cross_dock_ratio  packaging_material_cost  quality_check_rate  \
# 0                    NaN                     4.60              0.1443
# 1                 0.2490                     5.22              0.1400
# 2                 0.1977                     4.26              0.1817
# 3                 0.1955                     4.89              0.1485
# 4                 0.2351                     5.16              0.1514
# ...                  ...                      ...                 ...
# 249995            0.2586                     4.17              0.0856
# 249996            0.2783                     5.61              0.0526
# 249997            0.2659                     4.94              0.0379
# 249998            0.1736                     4.40              0.0320
# 249999            0.2151                     4.02              0.0320
#
#         outbound_truck_wait_min  dock_to_stock_hours  kpi_otd_pct  \
# 0                           8.1                 7.92         86.6
# 1                           NaN                 5.48         83.9
# 2                          10.7                 6.88         82.1
# 3                          10.7                 6.76         87.9
# 4                          12.4                 9.03         83.8
# ...                         ...                  ...          ...
# 249995                     16.0                 9.47         99.0
# 249996                     19.6                11.41          NaN
# 249997                     16.5                13.26         95.9
# 249998                     20.2                11.04         98.7
# 249999                     18.8                 9.71         96.4
#
#         backorder_ratio  shift_handover_delay_min  sort_accuracy_pct
# 0                0.0787                      5.12                NaN
# 1                0.0850                      5.77              94.88
# 2                0.1052                       NaN              94.40
# 3                0.0920                      4.53              93.72
# 4                0.0843                      3.99              95.02
# ...                 ...                       ...                ...
# 249995              NaN                      4.47              97.13
# 249996           0.0438                       NaN              96.73
# 249997              NaN                      3.24              98.86
# 249998           0.0519                      1.97              98.63
# 249999           0.0280                      0.80                NaN
#
# [250000 rows x 94 columns]

# %% [markdown]
# #
# ### **🌡️ 8. 창고 내부 환경**
# * warehouse_temp_avg → 창고 평균 온도
# * humidity_pct → 습도
# * lighting_level_lux → 조도
# * ambient_noise_db → 소음 수준
# * floor_vibration_idx → 바닥 진동 지수
# * air_quality_idx → 공기질 지수
# * co2_level_ppm → 이산화탄소 농도
#
# ### **🌦️ 9. 외부 환경**
# * external_temp_c → 외부 온도
# * wind_speed_kmh → 풍속
# * precipitation_mm → 강수량

# %%
env = df[["warehouse_temp_avg","humidity_pct","lighting_level_lux",
        "ambient_noise_db","floor_vibration_idx",
        "air_quality_idx","co2_level_ppm",
        "external_temp_c","wind_speed_kmh","precipitation_mm"]]
env
# Out:
#         warehouse_temp_avg  humidity_pct  lighting_level_lux  \
# 0                      NaN          59.1               200.0
# 1                    19.52          62.7               217.0
# 2                      NaN          67.1               200.0
# 3                    18.73          51.7               261.0
# 4                    20.51          55.6               221.0
# ...                    ...           ...                 ...
# 249995               17.46          20.5               383.0
# 249996               15.11          20.0               457.0
# 249997               16.71          30.8               488.0
# 249998               15.00          25.4               348.0
# 249999               17.49          23.8               396.0
#
#         ambient_noise_db  floor_vibration_idx  air_quality_idx  co2_level_ppm  \
# 0                   75.1               0.7036             12.2          804.0
# 1                   83.3               0.7158             24.8          619.0
# 2                    NaN               0.4420             10.2          834.0
# 3                   79.0               0.5258              3.9          874.0
# 4                    NaN               0.5129              5.8          891.0
# ...                  ...                  ...              ...            ...
# 249995              50.0               0.7879             51.4          447.0
# 249996              57.5               0.7686              NaN          497.0
# 249997              56.9               0.7862             80.4          400.0
# 249998              50.0               0.6488             84.7          400.0
# 249999              59.1               0.8220             48.3          408.0
#
#         external_temp_c  wind_speed_kmh  precipitation_mm
# 0                  -2.8             NaN              26.7
# 1                   NaN            29.1              19.7
# 2                   1.2            34.1              26.7
# 3                  -0.5            33.5              23.7
# 4                  -5.0             NaN              21.1
# ...                 ...             ...               ...
# 249995              4.1            21.2              26.9
# 249996              9.1            24.1               NaN
# 249997              9.4            25.7              20.0
# 249998              2.0            30.5              19.1
# 249999             -0.9            33.5              19.4
#
# [250000 rows x 10 columns]

# %%
missing = env.isnull().sum()

colors = sns.color_palette("rocket", len(missing))

plt.figure(figsize=(12, 5))
missing.plot(kind='bar', color=colors)

plt.title('Missing Values - env')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# #
# ### **상관관계 분석**
# * 상관관계가 없는 것으로 판단

# %%
corr = env.corr()
corr
# Out:
#                      warehouse_temp_avg  humidity_pct  lighting_level_lux  \
# warehouse_temp_avg             1.000000     -0.000065            0.006275
# humidity_pct                  -0.000065      1.000000            0.017515
# lighting_level_lux             0.006275      0.017515            1.000000
# ambient_noise_db               0.004040      0.012524            0.003338
# floor_vibration_idx            0.002326      0.009376            0.014716
# air_quality_idx               -0.003290      0.013667           -0.016022
# co2_level_ppm                  0.019248     -0.008129           -0.003886
# external_temp_c                0.004174      0.009410            0.002491
# wind_speed_kmh                -0.004899      0.000758            0.000101
# precipitation_mm              -0.009501     -0.002991           -0.007846
#
#                      ambient_noise_db  floor_vibration_idx  air_quality_idx  \
# warehouse_temp_avg           0.004040             0.002326        -0.003290
# humidity_pct                 0.012524             0.009376         0.013667
# lighting_level_lux           0.003338             0.014716        -0.016022
# ambient_noise_db             1.000000             0.012210        -0.002494
# floor_vibration_idx          0.012210             1.000000        -0.002389
# air_quality_idx             -0.002494            -0.002389         1.000000
# co2_level_ppm               -0.004180             0.010462        -0.000190
# external_temp_c             -0.005067            -0.002721        -0.006552
# wind_speed_kmh              -0.006138             0.006137         0.011120
# precipitation_mm            -0.004976            -0.005284        -0.021050
#
#                      co2_level_ppm  external_temp_c  wind_speed_kmh  \
# warehouse_temp_avg        0.019248         0.004174       -0.004899
# humidity_pct             -0.008129         0.009410        0.000758
# lighting_level_lux       -0.003886         0.002491        0.000101
# ambient_noise_db         -0.004180        -0.005067       -0.006138
# floor_vibration_idx       0.010462        -0.002721        0.006137
# air_quality_idx          -0.000190        -0.006552        0.011120
# co2_level_ppm             1.000000        -0.006025       -0.006231
# external_temp_c          -0.006025         1.000000        0.006462
# wind_speed_kmh           -0.006231         0.006462        1.000000
# precipitation_mm         -0.012655         0.012575        0.001174
#
#                      precipitation_mm
# warehouse_temp_avg          -0.009501
# humidity_pct                -0.002991
# lighting_level_lux          -0.007846
# ambient_noise_db            -0.004976
# floor_vibration_idx         -0.005284
# air_quality_idx             -0.021050
# co2_level_ppm               -0.012655
# external_temp_c              0.012575
# wind_speed_kmh               0.001174
# precipitation_mm             1.000000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='Blues', fmt=".2f")

plt.title('Correlation - Env Group')
plt.xticks(rotation=45)
plt.show()
