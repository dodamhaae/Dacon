# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
df = pd.read_csv('Smart-Warehouse-Delay/data/train.csv')
df
# Out:
#                   ID layout_id scenario_id  order_inflow_15m  unique_sku_15m  \
# 0       TRAIN_000000    WH_136    SC_07598              51.0            96.0
# 1       TRAIN_000001    WH_136    SC_07598               NaN            93.0
# 2       TRAIN_000002    WH_136    SC_07598              92.0           115.0
# 3       TRAIN_000003    WH_136    SC_07598              77.0           110.0
# 4       TRAIN_000004    WH_136    SC_07598               NaN           122.0
# ...              ...       ...         ...               ...             ...
# 249995  TRAIN_249995    WH_174    SC_05114              39.0             NaN
# 249996  TRAIN_249996    WH_174    SC_05114              69.0            96.0
# 249997  TRAIN_249997    WH_174    SC_05114              61.0           123.0
# 249998  TRAIN_249998    WH_174    SC_05114              54.0            97.0
# 249999  TRAIN_249999    WH_174    SC_05114              48.0            69.0
#
# ...

# %% [markdown]
# #
# ### **📊 11. 운영 KPI / 성과**
# * kpi_otd_pct → 정시 출고율 (On-time delivery)
# * backorder_ratio → 백오더 비율
# * outbound_truck_wait_min → 출고 트럭 대기 시간
# * dock_to_stock_hours → 입고→재고 반영 시간
# * inventory_turnover_rate → 재고 회전율
# * daily_forecast_accuracy → 수요 예측 정확도

# %%
kpi = df[["kpi_otd_pct","backorder_ratio","outbound_truck_wait_min",
        "dock_to_stock_hours","inventory_turnover_rate",
        "daily_forecast_accuracy"]]
kpi
# Out:
#         kpi_otd_pct  backorder_ratio  outbound_truck_wait_min  \
# 0              86.6           0.0787                      8.1
# 1              83.9           0.0850                      NaN
# 2              82.1           0.1052                     10.7
# 3              87.9           0.0920                     10.7
# 4              83.8           0.0843                     12.4
# ...             ...              ...                      ...
# 249995         99.0              NaN                     16.0
# 249996          NaN           0.0438                     19.6
# 249997         95.9              NaN                     16.5
# 249998         98.7           0.0519                     20.2
# 249999         96.4           0.0280                     18.8
#
#         dock_to_stock_hours  inventory_turnover_rate  daily_forecast_accuracy
# 0                      7.92                     1.33                   0.7206
# ...

# %%
missing = kpi.isnull().sum()

colors = sns.color_palette("rocket", len(missing))

plt.figure(figsize=(12, 5))
missing.plot(kind='bar', color=colors)

plt.title('Missing Values - kpi')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# #
# ### **상관관계 분석**
# * 상관관계가 없는 것으로 판단

# %%
corr = kpi.corr()
corr
# Out:
#                          kpi_otd_pct  backorder_ratio  \
# kpi_otd_pct                 1.000000        -0.110882
# backorder_ratio            -0.110882         1.000000
# outbound_truck_wait_min    -0.178012         0.114961
# dock_to_stock_hours        -0.066171         0.034487
# inventory_turnover_rate    -0.117159         0.273536
# daily_forecast_accuracy     0.109047        -0.130899
#
#                          outbound_truck_wait_min  dock_to_stock_hours  \
# kpi_otd_pct                            -0.178012            -0.066171
# backorder_ratio                         0.114961             0.034487
# outbound_truck_wait_min                 1.000000            -0.005257
# dock_to_stock_hours                    -0.005257             1.000000
# inventory_turnover_rate                 0.134333             0.051097
# daily_forecast_accuracy                -0.106697            -0.053926
#
#                          inventory_turnover_rate  daily_forecast_accuracy
# ...

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='Blues', fmt=".2f")

plt.title('Correlation - KPI Group')
plt.xticks(rotation=45)
plt.show()
