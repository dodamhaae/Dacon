# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/Smart-Warehouse-Delay/train.csv')
test = pd.read_csv('../data/Smart-Warehouse-Delay/test.csv')

# %% [markdown]
# #
# ### **🔋 3. 배터리 & 충전**
# * battery_mean → 평균 배터리 잔량
# * battery_std → 배터리 잔량 편차
# * low_battery_ratio → 배터리 부족 로봇 비율
# * charge_queue_length → 충전 대기 줄 길이
# * avg_charge_wait → 평균 충전 대기 시간
# * charge_efficiency_pct → 충전 효율
# * battery_cycle_count_avg → 평균 충전 사이클 수

# %%
battery = df[["battery_mean","battery_std","low_battery_ratio",
        "charge_queue_length","avg_charge_wait",
        "charge_efficiency_pct","battery_cycle_count_avg"]]
battery
# Out:
#         battery_mean  battery_std  low_battery_ratio  charge_queue_length  \
# 0              70.58          NaN                0.0                  0.0
# 1              69.87        17.60                0.0                  0.0
# 2              69.15        17.60                NaN                  0.0
# 3              68.43        17.60                0.0                  0.0
# 4              67.71        17.60                0.0                  0.0
# ...              ...          ...                ...                  ...
# 249995         59.28        17.76                0.0                  0.0
# 249996         58.78        17.76                NaN                  0.0
# 249997         58.27        17.76                0.0                  0.0
# 249998           NaN        17.76                0.0                  0.0
# 249999         57.26        17.76                0.0                  0.0
#
#         avg_charge_wait  charge_efficiency_pct  battery_cycle_count_avg
# 0                   0.0                   93.0                    201.0
# 1                   NaN                   90.8                    247.0
# 2                   0.0                   88.1                    226.0
# 3                   0.0                   91.6                      NaN
# 4                   0.0                   90.4                    205.0
# ...                 ...                    ...                      ...
# 249995              0.0                   83.8                    233.0
# 249996              0.0                   84.0                    297.0
# 249997              0.0                    NaN                    238.0
# 249998              0.0                   86.5                    311.0
# 249999              0.0                   87.9                    198.0
#
# [250000 rows x 7 columns]

# %%
battery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   battery_mean             219680 non-null  float64
#  1   battery_std              220621 non-null  float64
#  2   low_battery_ratio        220596 non-null  float64
#  3   charge_queue_length      220450 non-null  float64
#  4   avg_charge_wait          219304 non-null  float64
#  5   charge_efficiency_pct    219948 non-null  float64
#  6   battery_cycle_count_avg  220045 non-null  float64
# dtypes: float64(7)
# memory usage: 13.4 MB

# %%
missing = battery.isnull().sum()

colors = sns.color_palette("rocket", len(missing))

plt.figure(figsize=(12, 5))
missing.plot(kind='bar', color=colors)

plt.title('Missing Values - robot')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# #
# ### **상관관계 분석**
# #### **🔋 1) 배터리 상태 vs 고갈 상태**
# 🔥 가장 중요한 관계
# battery_mean ↔ low_battery_ratio = **-0.93** (매우 강함)
#
# - 배터리 평균 낮아질수록 → 저배터리 로봇 비율 급증
# - 거의 동일한 정보 수준 (반대 방향)
#
# 📌 결론: 둘 중 하나는 중복 가능성 매우 높음
# ####
# #### **🚨 2) 배터리 고갈 ↔ 충전 병목**
# low_battery_ratio ↔ charge_queue_length = **0.79**
# low_battery_ratio ↔ avg_charge_wait = **0.78**
#
# - 배터리 부족 많아짐 → 충전 줄 길어짐
# - 충전 대기 시간 증가
#
# 📌 의미: 배터리 고갈 = 충전 병목 발생
# ####
# #### **⏳ 3) 충전 병목 내부 구조**
# charge_queue_length ↔ avg_charge_wait = **0.86** (매우 강함)
#
# - 충전 대기 줄 길면 → 대기 시간도 자동 증가
# - 거의 같은 개념 수준
#
# 📌 결론: 둘 중 하나는 줄여도 될 정도로 중복

# %%
corr = battery.corr()
corr
# Out:
#                          battery_mean  battery_std  low_battery_ratio  \
# battery_mean                 1.000000    -0.530559          -0.933971
# battery_std                 -0.530559     1.000000           0.629518
# low_battery_ratio           -0.933971     0.629518           1.000000
# charge_queue_length         -0.720402     0.563213           0.794664
# avg_charge_wait             -0.714075     0.455589           0.776675
# charge_efficiency_pct        0.400234    -0.212473          -0.375327
# battery_cycle_count_avg     -0.323042     0.250973           0.356708
#
#                          charge_queue_length  avg_charge_wait  \
# battery_mean                       -0.720402        -0.714075
# battery_std                         0.563213         0.455589
# low_battery_ratio                   0.794664         0.776675
# charge_queue_length                 1.000000         0.856635
# avg_charge_wait                     0.856635         1.000000
# charge_efficiency_pct              -0.290978        -0.286983
# battery_cycle_count_avg             0.455280         0.386328
#
#                          charge_efficiency_pct  battery_cycle_count_avg
# battery_mean                          0.400234                -0.323042
# battery_std                          -0.212473                 0.250973
# low_battery_ratio                    -0.375327                 0.356708
# charge_queue_length                  -0.290978                 0.455280
# avg_charge_wait                      -0.286983                 0.386328
# charge_efficiency_pct                 1.000000                -0.133462
# battery_cycle_count_avg              -0.133462                 1.000000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='Blues', fmt=".2f")

plt.title('Correlation - Battery Group')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ###
# ### **결측치 채우기**
# #### 1) train datasets
# ① battery_mean ↔ low_battery_ratio = **-0.93**

# %%
battery[["battery_mean", "low_battery_ratio"]]
# Out:
#         battery_mean  low_battery_ratio
# 0              70.58                0.0
# 1              69.87                0.0
# 2              69.15                NaN
# 3              68.43                0.0
# 4              67.71                0.0
# ...              ...                ...
# 249995         59.28                0.0
# 249996         58.78                NaN
# 249997         58.27                0.0
# 249998           NaN                0.0
# 249999         57.26                0.0
#
# [250000 rows x 2 columns]

# %%
# 각각 결측치 개수
battery_mean_na = battery["battery_mean"].isnull().sum()
low_ratio_na = battery["low_battery_ratio"].isnull().sum()

# 둘 다 결측치인 경우
both_na = battery[
    battery["battery_mean"].isnull() &
    battery["low_battery_ratio"].isnull()
].shape[0]

nan_counts = {
    'battery_mean NaN': battery_mean_na,
    'low_battery_ratio NaN': low_ratio_na,
    'Both NaN': both_na
}

plt.figure(figsize=(8,5))
plt.bar(nan_counts.keys(), nan_counts.values(), color=colors)

plt.title('Missing Values')
plt.ylabel('Count')
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# #####
# low_battery_ratio 기준 결측치 **"battery_mean"** 채우기

# %%
battery["battery_mean"] = battery["battery_mean"].fillna(
    (1 - battery["low_battery_ratio"]) * 100
)

# %%
# 각각 결측치 개수
battery_mean_na = battery["battery_mean"].isnull().sum()
low_ratio_na = battery["low_battery_ratio"].isnull().sum()

# 둘 다 결측치인 경우
both_na = battery[
    battery["battery_mean"].isnull() &
    battery["low_battery_ratio"].isnull()
].shape[0]

nan_counts = {
    'battery_mean NaN': battery_mean_na,
    'low_battery_ratio NaN': low_ratio_na,
    'Both NaN': both_na
}

plt.figure(figsize=(8,5))
plt.bar(nan_counts.keys(), nan_counts.values(), color=colors)

plt.title('Missing Values')
plt.ylabel('Count')
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# #####
# battery_mean 기준 결측치 **"low_battery_ratio"** 채우기

# %%
battery["low_battery_ratio"] = battery["low_battery_ratio"].fillna(
    1 - (battery["battery_mean"] / 100)
)

# %%
# 각각 결측치 개수
battery_mean_na = battery["battery_mean"].isnull().sum()
low_ratio_na = battery["low_battery_ratio"].isnull().sum()

# 둘 다 결측치인 경우
both_na = battery[
    battery["battery_mean"].isnull() &
    battery["low_battery_ratio"].isnull()
].shape[0]

nan_counts = {
    'battery_mean NaN': battery_mean_na,
    'low_battery_ratio NaN': low_ratio_na,
    'Both NaN': both_na
}

plt.figure(figsize=(8,5))
plt.bar(nan_counts.keys(), nan_counts.values(), color=colors)

plt.title('Missing Values')
plt.ylabel('Count')
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# #####
# 결측치 **"battery_mean"**, **"low_battery_ratio"** 중앙값으로 채우기

# %%
battery['battery_mean'] = battery['battery_mean'].fillna(battery['battery_mean'].median())
battery['low_battery_ratio'] = battery['low_battery_ratio'].fillna(battery['low_battery_ratio'].median())

# %%
# 각각 결측치 개수
battery_mean_na = battery["battery_mean"].isnull().sum()
low_ratio_na = battery["low_battery_ratio"].isnull().sum()

# 둘 다 결측치인 경우
both_na = battery[
    battery["battery_mean"].isnull() &
    battery["low_battery_ratio"].isnull()
].shape[0]

nan_counts = {
    'battery_mean NaN': battery_mean_na,
    'low_battery_ratio NaN': low_ratio_na,
    'Both NaN': both_na
}

plt.figure(figsize=(8,5))
plt.bar(nan_counts.keys(), nan_counts.values(), color=colors)

plt.title('Missing Values')
plt.ylabel('Count')
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ####
# #### 2) test datasets

# %%
test_battery = test[["battery_mean","battery_std","low_battery_ratio",
        "charge_queue_length","avg_charge_wait",
        "charge_efficiency_pct","battery_cycle_count_avg"]]
test_battery
# Out:
#        battery_mean  battery_std  low_battery_ratio  charge_queue_length  \
# 0               NaN          NaN             0.0000                  0.0
# 1             66.59        17.45             0.0000                  0.0
# 2             63.92        17.56             0.0000                  0.0
# 3             61.89        17.29             0.0000                  0.0
# 4             60.12        17.36             0.0227                  0.0
# ...             ...          ...                ...                  ...
# 49995         48.96        16.71             0.0556                  0.0
# 49996         48.94        15.78             0.0000                  0.0
# 49997         48.41          NaN             0.0556                  NaN
# 49998         49.34        15.53             0.0000                  0.0
# 49999         49.77        18.11             0.0556                  0.0
#
#        avg_charge_wait  charge_efficiency_pct  battery_cycle_count_avg
# 0                  0.0                   91.0                     98.0
# 1                  0.0                   94.8                     80.0
# 2                  0.0                   98.5                     61.0
# 3                  0.0                   88.7                     81.0
# 4                  0.0                   89.2                     50.0
# ...                ...                    ...                      ...
# 49995              NaN                   80.0                     85.0
# 49996              0.0                   81.2                     82.0
# 49997              0.0                   85.5                    119.0
# 49998              NaN                   83.8                      NaN
# 49999              0.0                   78.7                    234.0
#
# [50000 rows x 7 columns]

# %%
battery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   battery_mean             250000 non-null  float64
#  1   battery_std              220621 non-null  float64
#  2   low_battery_ratio        250000 non-null  float64
#  3   charge_queue_length      220450 non-null  float64
#  4   avg_charge_wait          219304 non-null  float64
#  5   charge_efficiency_pct    219948 non-null  float64
#  6   battery_cycle_count_avg  220045 non-null  float64
# dtypes: float64(7)
# memory usage: 13.4 MB

# %%
missing = test_battery.isnull().sum()

colors = sns.color_palette("rocket", len(missing))

plt.figure(figsize=(12, 5))
missing.plot(kind='bar', color=colors)

plt.title('Missing Values - robot')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
test_battery[["battery_mean", "low_battery_ratio"]]
# Out:
#        battery_mean  low_battery_ratio
# 0               NaN             0.0000
# 1             66.59             0.0000
# 2             63.92             0.0000
# 3             61.89             0.0000
# 4             60.12             0.0227
# ...             ...                ...
# 49995         48.96             0.0556
# 49996         48.94             0.0000
# 49997         48.41             0.0556
# 49998         49.34             0.0000
# 49999         49.77             0.0556
#
# [50000 rows x 2 columns]

# %%
# 각각 결측치 개수
battery_mean_na = test_battery["battery_mean"].isnull().sum()
low_ratio_na = test_battery["low_battery_ratio"].isnull().sum()

# 둘 다 결측치인 경우
both_na = test_battery[
    test_battery["battery_mean"].isnull() &
    test_battery["low_battery_ratio"].isnull()
].shape[0]

nan_counts = {
    'battery_mean NaN': battery_mean_na,
    'low_battery_ratio NaN': low_ratio_na,
    'Both NaN': both_na
}

plt.figure(figsize=(8,5))
plt.bar(nan_counts.keys(), nan_counts.values(), color=colors)

plt.title('Missing Values')
plt.ylabel('Count')
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# #####
# low_battery_ratio 기준 결측치 **"battery_mean"** 채우기

# %%
test_battery["battery_mean"] = test_battery["battery_mean"].fillna(
    (1 - test_battery["low_battery_ratio"]) * 100
)

# %%
# 각각 결측치 개수
battery_mean_na = test_battery["battery_mean"].isnull().sum()
low_ratio_na = test_battery["low_battery_ratio"].isnull().sum()

# 둘 다 결측치인 경우
both_na = test_battery[
    test_battery["battery_mean"].isnull() &
    test_battery["low_battery_ratio"].isnull()
].shape[0]

nan_counts = {
    'battery_mean NaN': battery_mean_na,
    'low_battery_ratio NaN': low_ratio_na,
    'Both NaN': both_na
}

plt.figure(figsize=(8,5))
plt.bar(nan_counts.keys(), nan_counts.values(), color=colors)

plt.title('Missing Values')
plt.ylabel('Count')
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# #####
# battery_mean 기준 결측치 **"low_battery_ratio"** 채우기

# %%
test_battery["low_battery_ratio"] = test_battery["low_battery_ratio"].fillna(
    1 - (test_battery["battery_mean"] / 100)
)

# %%
# 각각 결측치 개수
battery_mean_na = test_battery["battery_mean"].isnull().sum()
low_ratio_na = test_battery["low_battery_ratio"].isnull().sum()

# 둘 다 결측치인 경우
both_na = test_battery[
    test_battery["battery_mean"].isnull() &
    test_battery["low_battery_ratio"].isnull()
].shape[0]

nan_counts = {
    'battery_mean NaN': battery_mean_na,
    'low_battery_ratio NaN': low_ratio_na,
    'Both NaN': both_na
}

plt.figure(figsize=(8,5))
plt.bar(nan_counts.keys(), nan_counts.values(), color=colors)

plt.title('Missing Values')
plt.ylabel('Count')
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# #####
# 결측치 **"battery_mean"**, **"low_battery_ratio"** 중앙값으로 채우기

# %%
test_battery['battery_mean'] = test_battery['battery_mean'].fillna(test_battery['battery_mean'].median())
test_battery['low_battery_ratio'] = test_battery['low_battery_ratio'].fillna(test_battery['low_battery_ratio'].median())

# %%
# 각각 결측치 개수
battery_mean_na = test_battery["battery_mean"].isnull().sum()
low_ratio_na = test_battery["low_battery_ratio"].isnull().sum()

# 둘 다 결측치인 경우
both_na = test_battery[
    test_battery["battery_mean"].isnull() &
    test_battery["low_battery_ratio"].isnull()
].shape[0]

nan_counts = {
    'battery_mean NaN': battery_mean_na,
    'low_battery_ratio NaN': low_ratio_na,
    'Both NaN': both_na
}

plt.figure(figsize=(8,5))
plt.bar(nan_counts.keys(), nan_counts.values(), color=colors)

plt.title('Missing Values')
plt.ylabel('Count')
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %%
df["battery_mean"] = battery["battery_mean"]
df["low_battery_ratio"] = battery["low_battery_ratio"]

# %%
test["battery_mean"] = test_battery["battery_mean"]
test["low_battery_ratio"] = test_battery["low_battery_ratio"]

# %%
df[["battery_mean", "low_battery_ratio"]].isnull().sum().to_frame(name="NaN")
# Out:
#                    NaN
# battery_mean         0
# low_battery_ratio    0

# %%
test[["battery_mean", "low_battery_ratio"]].isnull().sum().to_frame(name="NaN")
# Out:
#                    NaN
# battery_mean         0
# low_battery_ratio    0

# %%
df.to_csv("battery_V1.csv", index=False)

# %%
test.to_csv("test_battery_V1.csv", index=False)
