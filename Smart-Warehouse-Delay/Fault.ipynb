# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
df = pd.read_csv('Smart-Warehouse-Delay/data/train_V1.csv')
df
# Out:
#                   ID layout_id scenario_id  order_inflow_15m  unique_sku_15m  \
# 0       TRAIN_000000    WH_136    SC_07598              51.0            96.0
# 1       TRAIN_000001    WH_136    SC_07598               NaN            93.0
# 2       TRAIN_000002    WH_136    SC_07598              92.0           115.0
# 3       TRAIN_000003    WH_136    SC_07598              77.0           110.0
# 4       TRAIN_000004    WH_136    SC_07598               NaN           122.0
# ...              ...       ...         ...               ...             ...
# 249995  TRAIN_249995    WH_174    SC_05114              39.0             NaN
# 249996  TRAIN_249996    WH_174    SC_05114              69.0            96.0
# 249997  TRAIN_249997    WH_174    SC_05114              61.0           123.0
# 249998  TRAIN_249998    WH_174    SC_05114              54.0            97.0
# 249999  TRAIN_249999    WH_174    SC_05114              48.0            69.0
#
# ...

# %% [markdown]
# #
# ### **🛠️ 5. 장애 / 유지보수**
# * fault_count_15m → 장애 발생 횟수
# * avg_recovery_time → 평균 복구 시간
# * maintenance_schedule_score → 유지보수 계획 점수
# * robot_firmware_update_days → 펌웨어 업데이트 후 경과일
# * fleet_age_months_avg → 로봇 평균 사용 기간

# %%
fault = df[["fault_count_15m","avg_recovery_time","maintenance_schedule_score",
        "robot_firmware_update_days","fleet_age_months_avg"]]
fault
# Out:
#         fault_count_15m  avg_recovery_time  maintenance_schedule_score  \
# 0                   0.0                0.0                        70.0
# 1                   0.0                0.0                        70.1
# 2                   0.0                0.0                        70.4
# 3                   0.0                0.0                        70.2
# 4                   0.0                0.0                        71.6
# ...                 ...                ...                         ...
# 249995              0.0                0.0                        89.2
# 249996              NaN                0.0                        89.9
# 249997              0.0                0.0                        88.5
# 249998              0.0                0.0                        88.4
# 249999              0.0                0.0                         NaN
#
#         robot_firmware_update_days  fleet_age_months_avg
# 0                             38.2                  15.5
# ...

# %%
missing = fault.isnull().sum()

colors = sns.color_palette("rocket", len(missing))

plt.figure(figsize=(12, 5))
missing.plot(kind='bar', color=colors)

plt.title('Missing Values - fault')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# #
# ### **상관관계 분석**

# %%
corr = fault.corr()
corr
# Out:
#                             fault_count_15m  avg_recovery_time  \
# fault_count_15m                    1.000000           0.683632
# avg_recovery_time                  0.683632           1.000000
# maintenance_schedule_score        -0.104537          -0.107402
# robot_firmware_update_days         0.304281           0.205636
# fleet_age_months_avg               0.056107           0.065727
#
#                             maintenance_schedule_score  \
# fault_count_15m                              -0.104537
# avg_recovery_time                            -0.107402
# maintenance_schedule_score                    1.000000
# robot_firmware_update_days                   -0.026758
# fleet_age_months_avg                         -0.137751
#
#                             robot_firmware_update_days  fleet_age_months_avg
# fault_count_15m                               0.304281              0.056107
# avg_recovery_time                             0.205636              0.065727
# ...

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='Blues', fmt=".2f")

plt.title('Correlation - Fault Group')
plt.xticks(rotation=45)
plt.show()
