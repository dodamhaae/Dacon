# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
from lightgbm import LGBMRegressor
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
train = pd.read_csv('battery_V5.csv')
test = pd.read_csv('test_battery_V5.csv')

print(f"학습 데이터 크기: {train.shape}")
print(f"테스트 데이터 크기: {test.shape}")
# Out:
# 학습 데이터 크기: (250000, 94)
# 테스트 데이터 크기: (50000, 93)

# %%
TARGET = 'avg_delay_minutes_next_30m'
ID_COLS = ['ID', 'layout_id', 'scenario_id']

feature_cols = [c for c in train.columns if c not in ID_COLS + [TARGET]]
print(f"피처 수: {len(feature_cols)}")
# Out:
# 피처 수: 90

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)
oof_preds = np.zeros(len(train))
test_preds = np.zeros(len(test))

for fold, (tr_idx, val_idx) in enumerate(kf.split(train)):
    print(f"── Fold {fold + 1} ──")
    X_tr = train.loc[tr_idx, feature_cols]
    y_tr = train.loc[tr_idx, TARGET]
    X_val = train.loc[val_idx, feature_cols]
    y_val = train.loc[val_idx, TARGET]

    model = LGBMRegressor(
        device='gpu',
        n_estimators=1000, learning_rate=0.05, max_depth=7,
        num_leaves=63, subsample=0.8, colsample_bytree=0.8,
        reg_alpha=0.1, reg_lambda=0.1, random_state=42, verbose=-1,
    )
    model.fit(
        X_tr, y_tr,
        eval_set=[(X_val, y_val)],
        callbacks=[lgb.early_stopping(50), lgb.log_evaluation(100)],
    )

    oof_preds[val_idx] = model.predict(X_val)
    test_preds += model.predict(test[feature_cols]) / 5
# Out:
# ── Fold 1 ──
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's l2: 496.433
# [200]	valid_0's l2: 475.765
# [300]	valid_0's l2: 462.555
# [400]	valid_0's l2: 452.574
# [500]	valid_0's l2: 444.629
# [600]	valid_0's l2: 437.997
# [700]	valid_0's l2: 431.463
# [800]	valid_0's l2: 425.817
# [900]	valid_0's l2: 421.451
# [1000]	valid_0's l2: 417.401
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's l2: 417.401
# ── Fold 2 ──
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's l2: 505.35
# [200]	valid_0's l2: 485.811
# [300]	valid_0's l2: 473.99
# [400]	valid_0's l2: 464.113
# [500]	valid_0's l2: 457.022
# [600]	valid_0's l2: 450.846
# [700]	valid_0's l2: 445.965
# [800]	valid_0's l2: 440.486
# [900]	valid_0's l2: 436.602
# [1000]	valid_0's l2: 432.991
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's l2: 432.991
# ── Fold 3 ──
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's l2: 467.763
# [200]	valid_0's l2: 447.975
# [300]	valid_0's l2: 434.495
# [400]	valid_0's l2: 425.361
# [500]	valid_0's l2: 418.546
# [600]	valid_0's l2: 411.9
# [700]	valid_0's l2: 406.497
# [800]	valid_0's l2: 402.573
# [900]	valid_0's l2: 398.387
# [1000]	valid_0's l2: 394.674
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's l2: 394.674
# ── Fold 4 ──
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's l2: 483.515
# [200]	valid_0's l2: 464.946
# [300]	valid_0's l2: 452.514
# [400]	valid_0's l2: 442.887
# [500]	valid_0's l2: 434.935
# [600]	valid_0's l2: 428.661
# [700]	valid_0's l2: 423.294
# [800]	valid_0's l2: 419.12
# [900]	valid_0's l2: 415.341
# [1000]	valid_0's l2: 411.696
# Did not meet early stopping. Best iteration is:
# [999]	valid_0's l2: 411.687
# ── Fold 5 ──
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's l2: 481.945
# [200]	valid_0's l2: 463.935
# [300]	valid_0's l2: 451.015
# [400]	valid_0's l2: 441.682
# [500]	valid_0's l2: 435.277
# [600]	valid_0's l2: 428.546
# [700]	valid_0's l2: 423.33
# [800]	valid_0's l2: 418.76
# [900]	valid_0's l2: 414.406
# [1000]	valid_0's l2: 411.073
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's l2: 411.073

# %%
oof_mae = mean_absolute_error(train[TARGET], oof_preds)
print(f"OOF MAE: {oof_mae:.4f}")
# Out:
# OOF MAE: 9.2436

# %%
submission = pd.DataFrame({'ID': test['ID'], TARGET: test_preds})
submission.to_csv('./submission_V8.csv', index=False)
print("submission.csv 저장 완료.")
# Out:
# submission.csv 저장 완료.
