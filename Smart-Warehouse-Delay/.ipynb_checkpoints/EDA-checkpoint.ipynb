# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/Smart-Warehouse-Delay/train.csv')
df
# Out:
#                   ID layout_id scenario_id  order_inflow_15m  unique_sku_15m  \
# 0       TRAIN_000000    WH_136    SC_07598              51.0            96.0
# 1       TRAIN_000001    WH_136    SC_07598               NaN            93.0
# 2       TRAIN_000002    WH_136    SC_07598              92.0           115.0
# 3       TRAIN_000003    WH_136    SC_07598              77.0           110.0
# 4       TRAIN_000004    WH_136    SC_07598               NaN           122.0
# ...              ...       ...         ...               ...             ...
# 249995  TRAIN_249995    WH_174    SC_05114              39.0             NaN
# 249996  TRAIN_249996    WH_174    SC_05114              69.0            96.0
# 249997  TRAIN_249997    WH_174    SC_05114              61.0           123.0
# 249998  TRAIN_249998    WH_174    SC_05114              54.0            97.0
# 249999  TRAIN_249999    WH_174    SC_05114              48.0            69.0
#
#         avg_items_per_order  urgent_order_ratio  heavy_item_ratio  \
# 0                      3.29              0.1176            0.1765
# 1                      2.55              0.0597               NaN
# 2                      2.49              0.0652            0.2283
# 3                      2.52              0.0649               NaN
# 4                      3.12              0.0667            0.3333
# ...                     ...                 ...               ...
# 249995                 2.28              0.0513            0.1795
# 249996                 2.22              0.0870            0.2319
# 249997                 2.62              0.0984            0.3934
# 249998                 2.65              0.1296            0.1667
# 249999                 2.35              0.0625            0.2500
#
#         cold_chain_ratio  sku_concentration  ...  racking_height_avg_m  \
# 0                 0.0392             0.3063  ...                   NaN
# 1                 0.0149                NaN  ...                  2.50
# 2                 0.0217             0.3063  ...                  3.87
# 3                 0.0390             0.3063  ...                  2.50
# 4                    NaN             0.3063  ...                   NaN
# ...                  ...                ...  ...                   ...
# 249995               NaN                NaN  ...                  8.10
# 249996            0.0290             0.2226  ...                  8.63
# 249997            0.0820             0.2226  ...                   NaN
# 249998            0.0185             0.2226  ...                  9.39
# 249999               NaN             0.2226  ...                  7.58
#
#         cross_dock_ratio  packaging_material_cost  quality_check_rate  \
# 0                    NaN                     4.60              0.1443
# 1                 0.2490                     5.22              0.1400
# 2                 0.1977                     4.26              0.1817
# 3                 0.1955                     4.89              0.1485
# 4                 0.2351                     5.16              0.1514
# ...                  ...                      ...                 ...
# 249995            0.2586                     4.17              0.0856
# 249996            0.2783                     5.61              0.0526
# 249997            0.2659                     4.94              0.0379
# 249998            0.1736                     4.40              0.0320
# 249999            0.2151                     4.02              0.0320
#
#         outbound_truck_wait_min  dock_to_stock_hours  kpi_otd_pct  \
# 0                           8.1                 7.92         86.6
# 1                           NaN                 5.48         83.9
# 2                          10.7                 6.88         82.1
# 3                          10.7                 6.76         87.9
# 4                          12.4                 9.03         83.8
# ...                         ...                  ...          ...
# 249995                     16.0                 9.47         99.0
# 249996                     19.6                11.41          NaN
# 249997                     16.5                13.26         95.9
# 249998                     20.2                11.04         98.7
# 249999                     18.8                 9.71         96.4
#
#         backorder_ratio  shift_handover_delay_min  sort_accuracy_pct
# 0                0.0787                      5.12                NaN
# 1                0.0850                      5.77              94.88
# 2                0.1052                       NaN              94.40
# 3                0.0920                      4.53              93.72
# 4                0.0843                      3.99              95.02
# ...                 ...                       ...                ...
# 249995              NaN                      4.47              97.13
# 249996           0.0438                       NaN              96.73
# 249997              NaN                      3.24              98.86
# 249998           0.0519                      1.97              98.63
# 249999           0.0280                      0.80                NaN
#
# [250000 rows x 94 columns]

# %%
layout = pd.read_csv('../data/Smart-Warehouse-Delay/layout_info.csv')
layout
# Out:
#     layout_id layout_type  aisle_width_avg  intersection_count  one_way_ratio  \
# 0      WH_001      narrow             2.08                34.0         0.3874
# 1      WH_002        grid             3.70                16.0         0.0054
# 2      WH_003        grid             2.54                52.0         0.0229
# 3      WH_004      hybrid             3.37                35.0         0.4836
# 4      WH_005        grid             3.68                48.0         0.0494
# ..        ...         ...              ...                 ...            ...
# 295    WH_296        grid             3.26                45.0         0.2777
# 296    WH_297      hybrid             2.14                25.0         0.1410
# 297    WH_298   hub_spoke             3.74                10.0         0.0107
# 298    WH_299      narrow             1.70                15.0         0.6002
# 299    WH_300   hub_spoke             3.90                 9.0         0.1795
#
#      pack_station_count  charger_count  layout_compactness  zone_dispersion  \
# 0                   9.0            8.0              0.8078           0.5867
# 1                   9.0           11.0              0.7339           0.4390
# 2                   5.0            3.0              0.5498           0.3708
# 3                   5.0           10.0              0.4821           0.5661
# 4                   8.0           13.0              0.6740           0.9970
# ..                  ...            ...                 ...              ...
# 295                 7.0            7.0              0.7694           0.7045
# 296                19.0           15.0              0.5534           0.1224
# 297                 4.0           10.0              0.3098           0.4970
# 298                 9.0           15.0              0.8984           0.9239
# 299                 8.0            8.0              0.4518           0.8956
#
#      robot_total  building_age_years  floor_area_sqm  ceiling_height_m  \
# 0             21                  20            3384               9.4
# 1             57                  26            8311               8.1
# 2             63                  39            9465               7.2
# 3            100                  40            7918              12.7
# 4             50                  33            5905               5.6
# ..           ...                 ...             ...               ...
# 295           19                  35            4080              10.9
# 296           30                  20            8782              12.2
# 297           26                  17            6635               9.6
# 298           58                  33            3744              14.7
# 299           14                  12            8365              11.9
#
#      fire_sprinkler_count  emergency_exit_count
# 0                      36                     5
# 1                      12                     2
# 2                      81                     2
# 3                      26                     5
# 4                      84                     9
# ..                    ...                   ...
# 295                    22                     9
# 296                    58                     2
# 297                    91                     6
# 298                    83                     3
# 299                    62                    10
#
# [300 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 94 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ID                          250000 non-null  object
#  1   layout_id                   250000 non-null  object
#  2   scenario_id                 250000 non-null  object
#  3   order_inflow_15m            220436 non-null  float64
#  4   unique_sku_15m              220076 non-null  float64
#  5   avg_items_per_order         220377 non-null  float64
#  6   urgent_order_ratio          220246 non-null  float64
#  7   heavy_item_ratio            220384 non-null  float64
#  8   cold_chain_ratio            220549 non-null  float64
#  9   sku_concentration           220301 non-null  float64
#  10  robot_active                250000 non-null  int64
#  11  robot_idle                  250000 non-null  int64
#  12  robot_charging              250000 non-null  int64
#  13  robot_utilization           250000 non-null  float64
#  14  avg_trip_distance           220234 non-null  float64
#  15  task_reassign_15m           220663 non-null  float64
#  16  battery_mean                219680 non-null  float64
#  17  battery_std                 220621 non-null  float64
#  18  low_battery_ratio           220596 non-null  float64
#  19  charge_queue_length         220450 non-null  float64
#  20  avg_charge_wait             219304 non-null  float64
#  21  congestion_score            217750 non-null  float64
#  22  max_zone_density            220396 non-null  float64
#  23  blocked_path_15m            220465 non-null  float64
#  24  near_collision_15m          220596 non-null  float64
#  25  fault_count_15m             220356 non-null  float64
#  26  avg_recovery_time           217471 non-null  float64
#  27  replenishment_overlap       220479 non-null  float64
#  28  pack_utilization            220470 non-null  float64
#  29  manual_override_ratio       220466 non-null  float64
#  30  avg_delay_minutes_next_30m  250000 non-null  float64
#  31  warehouse_temp_avg          220389 non-null  float64
#  32  humidity_pct                220119 non-null  float64
#  33  day_of_week                 220413 non-null  float64
#  34  external_temp_c             220298 non-null  float64
#  35  wind_speed_kmh              220377 non-null  float64
#  36  precipitation_mm            220355 non-null  float64
#  37  lighting_level_lux          220297 non-null  float64
#  38  ambient_noise_db            220543 non-null  float64
#  39  floor_vibration_idx         220446 non-null  float64
#  40  return_order_ratio          220268 non-null  float64
#  41  air_quality_idx             220678 non-null  float64
#  42  co2_level_ppm               220486 non-null  float64
#  43  hvac_power_kw               220530 non-null  float64
#  44  wms_response_time_ms        220302 non-null  float64
#  45  scanner_error_rate          220589 non-null  float64
#  46  wifi_signal_db              220548 non-null  float64
#  47  network_latency_ms          220296 non-null  float64
#  48  worker_avg_tenure_months    220196 non-null  float64
#  49  safety_score_monthly        220234 non-null  float64
#  50  label_print_queue           220423 non-null  float64
#  51  barcode_read_success_rate   220138 non-null  float64
#  52  ups_battery_pct             220398 non-null  float64
#  53  lighting_zone_variance      220358 non-null  float64
#  54  shift_hour                  220203 non-null  float64
#  55  staff_on_floor              220412 non-null  float64
#  56  forklift_active_count       220317 non-null  float64
#  57  loading_dock_util           220500 non-null  float64
#  58  conveyor_speed_mps          220354 non-null  float64
#  59  prev_shift_volume           220482 non-null  float64
#  60  avg_package_weight_kg       220366 non-null  float64
#  61  inventory_turnover_rate     220147 non-null  float64
#  62  daily_forecast_accuracy     220429 non-null  float64
#  63  order_wave_count            220509 non-null  float64
#  64  pick_list_length_avg        220363 non-null  float64
#  65  express_lane_util           220473 non-null  float64
#  66  bulk_order_ratio            220463 non-null  float64
#  67  staging_area_util           220108 non-null  float64
#  68  cold_storage_temp_c         220392 non-null  float64
#  69  pallet_wrap_time_min        220374 non-null  float64
#  70  fleet_age_months_avg        220047 non-null  float64
#  71  maintenance_schedule_score  220483 non-null  float64
#  72  robot_firmware_update_days  220594 non-null  float64
#  73  avg_idle_duration_min       220339 non-null  float64
#  74  charge_efficiency_pct       219948 non-null  float64
#  75  battery_cycle_count_avg     220045 non-null  float64
#  76  agv_task_success_rate       220594 non-null  float64
#  77  robot_calibration_score     220056 non-null  float64
#  78  aisle_traffic_score         220641 non-null  float64
#  79  zone_temp_variance          220398 non-null  float64
#  80  path_optimization_score     220375 non-null  float64
#  81  intersection_wait_time_avg  220435 non-null  float64
#  82  storage_density_pct         220551 non-null  float64
#  83  vertical_utilization        220397 non-null  float64
#  84  racking_height_avg_m        220358 non-null  float64
#  85  cross_dock_ratio            220457 non-null  float64
#  86  packaging_material_cost     220273 non-null  float64
#  87  quality_check_rate          220448 non-null  float64
#  88  outbound_truck_wait_min     220544 non-null  float64
#  89  dock_to_stock_hours         220532 non-null  float64
#  90  kpi_otd_pct                 220595 non-null  float64
#  91  backorder_ratio             220448 non-null  float64
#  92  shift_handover_delay_min    220466 non-null  float64
#  93  sort_accuracy_pct           220230 non-null  float64
# dtypes: float64(88), int64(3), object(3)
# memory usage: 179.3+ MB

# %% [markdown]
# #####
# 타깃 결측치 확인

# %%
int(df['avg_delay_minutes_next_30m'].isnull().sum())
# Out:
# 0

# %%
missing = df.isnull().sum()

cols = missing.index
n = len(cols)
chunk_size = 10

for i in range(0, n, chunk_size):
    subset = missing.iloc[i:i+chunk_size]
    
    plt.figure(figsize=(12, 5))
    subset.plot(kind='bar')
    
    plt.title(f'Missing Values ({i} ~ {i+len(subset)-1})')
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()

# %%
col_groups = {
    "order": [
        "order_inflow_15m","unique_sku_15m","avg_items_per_order",
        "urgent_order_ratio","bulk_order_ratio","order_wave_count",
        "pick_list_length_avg","express_lane_util"
    ],
    
    "robot": [
        "robot_active","robot_idle","robot_charging","robot_utilization",
        "avg_idle_duration_min","agv_task_success_rate","robot_calibration_score"
    ],
    
    "battery": [
        "battery_mean","battery_std","low_battery_ratio",
        "charge_queue_length","avg_charge_wait",
        "charge_efficiency_pct","battery_cycle_count_avg"
    ],
    
    "traffic": [
        "congestion_score","max_zone_density","blocked_path_15m",
        "near_collision_15m","aisle_traffic_score",
        "intersection_wait_time_avg","path_optimization_score"
    ],
    
    "fault": [
        "fault_count_15m","avg_recovery_time","maintenance_schedule_score",
        "robot_firmware_update_days","fleet_age_months_avg"
    ],
    
    "operation": [
        "pack_utilization","replenishment_overlap","manual_override_ratio",
        "staging_area_util","loading_dock_util",
        "conveyor_speed_mps","pallet_wrap_time_min"
    ],
    
    "staff": [
        "staff_on_floor","worker_avg_tenure_months",
        "shift_hour","shift_handover_delay_min"
    ],
    
    "env_internal": [
        "warehouse_temp_avg","humidity_pct","lighting_level_lux",
        "ambient_noise_db","floor_vibration_idx",
        "air_quality_idx","co2_level_ppm"
    ],
    
    "env_external": [
        "external_temp_c","wind_speed_kmh","precipitation_mm"
    ],
    
    "it_system": [
        "wms_response_time_ms","scanner_error_rate","wifi_signal_db",
        "network_latency_ms","barcode_read_success_rate","label_print_queue"
    ],
    
    "kpi": [
        "kpi_otd_pct","backorder_ratio","outbound_truck_wait_min",
        "dock_to_stock_hours","inventory_turnover_rate",
        "daily_forecast_accuracy"
    ],
    
    "product": [
        "heavy_item_ratio","cold_chain_ratio","avg_package_weight_kg",
        "sku_concentration","return_order_ratio"
    ],
    
    "space": [
        "storage_density_pct","vertical_utilization",
        "racking_height_avg_m","cross_dock_ratio"
    ]
}

# %%
missing = df.isnull().sum()

for group_name, col_list in col_groups.items():
    # df에 실제 존재하는 컬럼만 필터 (혹시 없는 컬럼 대비)
    valid_cols = [col for col in col_list if col in missing.index]
    
    if len(valid_cols) == 0:
        continue
    
    subset = missing[valid_cols]
    
    plt.figure(figsize=(12, 5))
    subset.plot(kind='bar')
    
    plt.title(f'Missing Values - {group_name}')
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()
